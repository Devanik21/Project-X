# %%
import google.generativeai as genai
import os
import PIL.Image
import io
import sys # Import sys for exit

# --- Configuration ---
# Replace with your actual API key
# It's recommended to store your API key securely, e.g., as an environment variable
# or using a secret management tool, rather than hardcoding it.
# Example using environment variable:
# API_KEY = os.getenv("GEMINI_API_KEY")
API_KEY = "AIzaSyDuMuSDMX4A33NYki7lgs6x13uxbHirMQk" # <<< --- PASTE YOUR KEY HERE --- >>>

# The specific image generation model to use
MODEL_NAME = "gemini-2.0-flash-exp-image-generation"

# The text prompt describing the image you want to generate
IMAGE_PROMPT = "A futuristic cityscape at sunset with flying cars" # Example prompt

# --- API Initialization ---
if API_KEY == "YOUR_API_KEY":
    print("Error: Please replace 'YOUR_API_KEY' with your actual Gemini API key.")
    sys.exit(1) # Exit if the key hasn't been replaced

try:
    genai.configure(api_key=API_KEY)
except Exception as e:
    print(f"Error configuring the Gemini API: {e}")
    print("Please ensure your API key is correct and you have internet connectivity.")
    sys.exit(1) # Exit on configuration error

# --- Image Generation ---
print(f"Generating image for prompt: '{IMAGE_PROMPT}' using model '{MODEL_NAME}'...")

try:
    # Initialize the generative model
    model = genai.GenerativeModel(MODEL_NAME)

    # Generate the image content
    # Note: Image generation models might have specific parameters.
    # Refer to the Gemini API documentation for details on available parameters
    # like number of images, aspect ratio, etc.
    response = model.generate_content(
        IMAGE_PROMPT,
        # Example of potential parameters (check documentation for actual support):
        # generation_config=genai.types.GenerationConfig(
        #     candidate_count=1, # Number of images to generate
        #     # Other parameters like negative_prompt, style_preset etc. might be available
        # )
    )

    # --- Process and Save the Image ---
    # Check if the response contains candidates and parts
    if response.candidates and response.candidates[0].content.parts:
        # Get the first part, assuming it contains the image data
        image_part = response.candidates[0].content.parts[0]

        # Check if the part has the 'blob' attribute containing the image bytes
        if hasattr(image_part, 'blob') and image_part.blob:
            # Get the raw image bytes
            image_bytes = image_part.blob

            # Create a PIL Image object from the bytes
            image = PIL.Image.open(io.BytesIO(image_bytes))

            # Define the output filename
            # Replace spaces and special characters in the prompt for a safe filename
            safe_prompt = "".join(c if c.isalnum() else "_" for c in IMAGE_PROMPT[:50])
            output_filename = f"generated_image_{safe_prompt}.png"

            # Save the image
            image.save(output_filename)
            print(f"Image successfully generated and saved as '{output_filename}'")

            # Optionally display the image if running in an environment that supports it
            # image.show()

        else:
            print("Error: The response part did not contain image blob data in the expected format.")
            # You might want to print the part structure for debugging:
            # print("Image part structure:", image_part)

    else:
        print("Error: Could not generate image. The response structure might be unexpected or generation failed.")
        # Print the response details for debugging if needed
        # print("Full response:", response)
        if hasattr(response, 'prompt_feedback'):
             print("Prompt Feedback:", response.prompt_feedback)


except Exception as e:
    print(f"An error occurred during image generation: {e}")
    # You might want to print the full response object here too for debugging
    # if 'response' in locals():
    #     print("Response object:", response)
    # Consider printing traceback for more detailed error info
    # import traceback
    # traceback.print_exc()
# Out:
# Generating image for prompt: 'A futuristic cityscape at sunset with flying cars' using model 'gemini-2.0-flash-exp-image-generation'...
# Error: The response part did not contain image blob data in the expected format.
